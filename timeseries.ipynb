# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Rates.csv')

# %%
df
# Out:
#             Ամսաթիվ  USD
# 03/01/2024   405.28  NaN
# 04/01/2024   405.42  NaN
# 05/01/2024   405.22  NaN
# 08/01/2024   405.23  NaN
# 09/01/2024   405.61  NaN
# ...             ...  ...
# 25/03/2024   396.05  NaN
# 26/03/2024   395.68  NaN
# 27/03/2024   394.71  NaN
# 28/03/2024   394.46  NaN
# 29/03/2024   393.28  NaN
#
# [62 rows x 2 columns]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#     Ամսաթիվ  USD
# 0    405.28  NaN
# 1    405.42  NaN
# 2    405.22  NaN
# 3    405.23  NaN
# 4    405.61  NaN
# ..      ...  ...
# 57   396.05  NaN
# 58   395.68  NaN
# 59   394.71  NaN
# 60   394.46  NaN
# 61   393.28  NaN
#
# [62 rows x 2 columns]

# %%
df.rename(columns={'Ամսաթիվ':'Usd'},inplace=True)

# %%
df
# Out:
#        Usd  USD
# 0   405.28  NaN
# 1   405.42  NaN
# 2   405.22  NaN
# 3   405.23  NaN
# 4   405.61  NaN
# ..     ...  ...
# 57  396.05  NaN
# 58  395.68  NaN
# 59  394.71  NaN
# 60  394.46  NaN
# 61  393.28  NaN
#
# [62 rows x 2 columns]

# %%
y_t_1 = df['Usd'][:-1]
y_t = df['Usd'][1:]

# %%
df = pd.DataFrame(data=y_t_1.values,columns=['t_1'])

# %%
df['t'] = y_t.values

# %%
df
# Out:
#        t_1       t
# 0   405.28  405.42
# 1   405.42  405.22
# 2   405.22  405.23
# 3   405.23  405.61
# 4   405.61  405.48
# ..     ...     ...
# 56  397.76  396.05
# 57  396.05  395.68
# 58  395.68  394.71
# 59  394.71  394.46
# 60  394.46  393.28
#
# [61 rows x 2 columns]

# %%
X = df.drop('t',axis=1)
y = df['t']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.40826822937823776

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9810602682610429

# %%
df
# Out:
#        t_1       t
# 0   405.28  405.42
# 1   405.42  405.22
# 2   405.22  405.23
# 3   405.23  405.61
# 4   405.61  405.48
# ..     ...     ...
# 56  397.76  396.05
# 57  396.05  395.68
# 58  395.68  394.71
# 59  394.71  394.46
# 60  394.46  393.28
#
# [61 rows x 2 columns]

# %%
model.predict(np.array([[394.46]]))
# Out:
# C:\Users\Asus\Desktop\jupiter\virtualcomputer\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([393.2236382])

# %%
model.predict(np.array([[393.2236382]]))
# Out:
# C:\Users\Asus\Desktop\jupiter\virtualcomputer\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([391.84459422])
